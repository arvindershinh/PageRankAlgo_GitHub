# %%
import numpy as np
import sympy as sy

# %% [markdown]
# url1 --> url3, url5
#
# url2 --> url1
#
# url3 --> url4, url2
#
# url4 --> url1
#
# url5 --> url3, url1, url2

# %%
pageRank = sy.Matrix([[0, 1, 0,   1, 1/3],
                      [0, 0, 1/2, 0, 1/3],
                      [1/2, 0, 0,   0, 1/3],
                      [0, 0, 1/2, 0,   0],
                      [1/2, 0, 0,   0,   0]])

# %%
rank0 = sy.Matrix([1,1,1,1,1])

# %%
rank1 = (pageRank*rank0*.85)+sy.Matrix([.15,.15,.15,.15,.15])
rank1
# Out:
# Matrix([
# [ 2.13333333333333],
# [0.858333333333333],
# [0.858333333333333],
# [            0.575],
# [            0.575]])

# %%
rank2 = (pageRank*rank1*.85)+sy.Matrix([.15,.15,.15,.15,.15])
rank2
# Out:
# Matrix([
# [          1.53125],
# [0.677708333333333],
# [ 1.21958333333333],
# [0.514791666666667],
# [ 1.05666666666667]])
